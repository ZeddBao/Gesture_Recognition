# %%
import matplotlib.pyplot as plt

model_list = ['128-float32', '128-float16', '64-float32', '64-float16', '32-float32', '32-float16', '16-float32', '16-float16']
mean_list = [1013.8628, 454.1309, 520.5435, 441.8086, 458.0011, 428.8492, 446.1697, 409.8419]
mean_list2 = [165.7844, 135.9014, 130.9845, 128.4089, 130.2170, 129.6310, 128.9521, 118.3812]
accuracy_list = [0.9301, 0.9301, 0.9752, 0.9724, 0.9566, 0.9566, 0.8918, 0.8923]

# 提取x和y值

# 绘制条形图
plt.bar(model_list, mean_list2, width=0.5, color='blue', label='Mean time (us)')

# 设置x轴和y轴标签
plt.xlabel('Model')
plt.ylabel('10000 rounds mean time (us)')
# plt.ylabel('Accuracy')
plt.ylim(110, 170)

# 设置图表标题
plt.title('Benchmark Results')

# 旋转x轴标签
plt.xticks(rotation=45)

# 显示图表
plt.show()
